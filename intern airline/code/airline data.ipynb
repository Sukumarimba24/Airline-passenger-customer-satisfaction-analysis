# %%
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk

# %%
airline=pd.read_csv("c:/pyth_files/airline_passenger_satisfaction.csv")
airline
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
airline.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
airline=airline.fillna(0)
airline.isnull().sum()
# Out:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# ...

# %%
airline['Satisfaction'] = airline['Satisfaction'].replace({
'Neutral or Dissatisfied': 0, 'Satisfied': 1
})
# Out:
# C:\Users\sukum\AppData\Local\Temp\ipykernel_3236\1348442979.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   airline['Satisfaction'] = airline['Satisfaction'].replace({

# %%
cleaneddata_df=pd.read_csv("cleaned airline passenger satisfaction_data.csv")
cleaneddata_df
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
cleaneddata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129880 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
cleaneddata_df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129880.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.407410                                1.526741
# min         0.000000                                0.000000
# ...

# %%
import seaborn as sns
import matplotlib .pyplot as plt

# %%
sns.countplot(data=cleaneddata_df,x ='Satisfaction')
plt.title("passenger satisfaction count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cleaneddata_df['Satisfaction'].value_counts().plot.pie(autopct='%1.1f%%', startangle=30)
plt.title('Satisfaction count')
plt.ylabel('')
plt.show()

# %%
sns.countplot(data=cleaneddata_df,x = 'Gender')
plt.title('Gender count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
service_columns = cleaneddata_df.columns[9:23].tolist()


from turtle import color


median_ratings = cleaneddata_df[cleaneddata_df['Satisfaction']==0][service_columns].median()
median_ratings.plot(kind='bar', color='black',edgecolor='yellow',figsize=(12, 6))
plt.title('Median Service Ratings by Satisfaction')
plt.ylabel('Median Rating')
plt.xlabel('Service Features')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
sns.countplot(data=cleaneddata_df,x="Type of Travel",hue="Satisfaction")
plt.title('Satisfaction by type of travel')
plt.xlabel('Type of travel')
plt.ylabel('Number of passengers')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(data=cleaneddata_df,x="Satisfaction",y= "Age")
plt.title("Age distribution by Satisfaction",color="red")
plt.ylabel("Age")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(data=cleaneddata_df,x="Satisfaction",y="Flight Distance")
plt.title("Flight distance vs satisfaction")
plt.xlabel("Satisfaction")
plt.ylabel("Flight distance")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
customer_satisfaction = cleaneddata_df.groupby(['Customer Type', 'Satisfaction']).size().unstack()

customer_satisfaction.plot(kind='bar', stacked=True, figsize=(5, 5))
plt.title("Satisfaction by Customer Type")
plt.xlabel("Customer Type")
plt.ylabel("Number of Passengers")
plt.legend(title='Satisfaction')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
cleaneddata_df['Departure and Arrival Time Convenience'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Ratings')
plt.ylabel('')
plt.show()

# %%
cleaneddata_df['In-flight Wifi Service'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Ratings')
plt.ylabel('')
plt.show()

# %%
cleaneddata_df['Age'].hist(bins=40, color='purple', edgecolor='white')
plt.title('Passenger Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
categorical_cols = cleaneddata_df.select_dtypes(include=['object']).columns
le = LabelEncoder()
for col in categorical_cols:
    cleaneddata_df[col] = le.fit_transform(cleaneddata_df[col])

# %%
X = cleaneddata_df.drop('Satisfaction', axis=1)
y = cleaneddata_df['Satisfaction']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8746920234062211
# Confusion Matrix:
#  [[13287  1436]
#  [ 1819  9434]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     14723
#            1       0.87      0.84      0.85     11253
#
#     accuracy                           0.87     25976
#    macro avg       0.87      0.87      0.87     25976
# weighted avg       0.87      0.87      0.87     25976

# %%
from matplotlib import cm
from numpy import test

cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Unsatisfied', 'Satisfied'], yticklabels=['Unsatisfied', 'Satisfied'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
